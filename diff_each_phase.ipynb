# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/home/ekim_reverse/study/Python.study/DATA_20191210_prep4.xlsx', sheet_name="filtered")

# %%
data_01 = pd.read_excel('/home/ekim_reverse/study/Python.study/DATA_20191210_prep4_1.xlsx', sheet_name="filtered")

# %%
data.head()
# Out:
#                 RID  SEX  phase  AS1_GLU  AS2_GLU  AS3_GLU  AS4_GLU  AS5_GLU  \
# 0  EPI18_079_000033    1      4      104      113      121      140      109
# 1  EPI18_079_000051    2      3       83       99      104      108       83
# 2  EPI18_079_000069    1      2       82      138      100       91       96
# 3  EPI18_079_000075    2      6       82       89      100       99      104
# 4  EPI18_079_000126    2      4       89      103      115      132      123
#
#    AS6_GLU  AS7_GLU  ...  AS6_HBA1C  AS7_HBA1C  AS1_HOMA  AS2_HOMA  AS3_HOMA  \
# 0      105      114  ...        5.9        6.0  1.335309  1.340000  1.830000
# 1       90      112  ...        5.3        5.7  1.578025  1.980000  1.753086
# 2      111      118  ...        5.6        5.9  2.247407  3.645926  2.469136
# 3       98      123  ...        6.7        6.1  0.749136  3.823704  2.754321
# 4      126      136  ...        6.7        7.1  1.186667  3.128148  0.792593
#
# ...

# %%
gluList = data.loc[:,"AS1_GLU":"AS7_GLU"]
altList = data.loc[:,"AS1_ALT":"AS7_ALT"]
tgList = data.loc[:,"AS1_TG":"AS7_TG"]
waistList = data.loc[:,"AS1_WAIST":"AS7_WAIST"]
fib4List = data.loc[:,"AS1_FIB4":"AS7_FIB4"]
hba1cList = data.loc[:,"AS1_HBA1C":"AS7_HBA1C"]
homaList = data.loc[:,"AS1_HOMA":"AS7_HOMA"]

# %%
gluList
# Out:
#       AS1_GLU  AS2_GLU  AS3_GLU  AS4_GLU  AS5_GLU  AS6_GLU  AS7_GLU
# 0         104      113      121      140      109      105      114
# 1          83       99      104      108       83       90      112
# 2          82      138      100       91       96      111      118
# 3          82       89      100       99      104       98      123
# 4          89      103      115      132      123      126      136
# ...       ...      ...      ...      ...      ...      ...      ...
# 2977       78       81      110       87       91       93       82
# 2978       86       91       87       95       92       88       93
# 2979       94       97       82       90       98       92       92
# 2980       89       88       80       87       89       97       90
# 2981       80       92       87       87       92       88       88
#
# [2982 rows x 7 columns]

# %%
df=pd.DataFrame()

# %%
data["phase"][0]
# Out:
# 4

# %%
gluList.columns = [1,2,3,4,5,6,7]
altList.columns = [1,2,3,4,5,6,7]
tgList.columns = [1,2,3,4,5,6,7]
waistList.columns = [1,2,3,4,5,6,7]
fib4List.columns = [1,2,3,4,5,6,7]
hba1cList.columns = [1,2,3,4,5,6,7]
homaList.columns = [1,2,3,4,5,6,7]

# %%
gluList_01 = data_01.loc[:,"AS1_GLU":"AS7_GLU"]
altList_01 = data_01.loc[:,"AS1_ALT":"AS7_ALT"]
tgList_01 = data_01.loc[:,"AS1_TG":"AS7_TG"]
waistList_01 = data_01.loc[:,"AS1_WAIST":"AS7_WAIST"]
fib4List_01 = data_01.loc[:,"AS1_FIB4":"AS7_FIB4"]
hba1cList_01 = data_01.loc[:,"AS1_HBA1C":"AS7_HBA1C"]
homaList_01 = data_01.loc[:,"AS1_HOMA":"AS7_HOMA"]

# %%
endData = []
for i in range(len(gluList)):
    for j in range(len(gluList.columns)):
        if data["phase"][i]==gluList.columns[j]:
            endData.append(gluList[j+1][i]-gluList[j][i])
df['glu_01'] = endData
print(df)
# Out:
#       glu_01
# 0         19
# 1          5
# 2         56
# 3         -6
# 4         17
# ...      ...
# 2977     -11
# 2978       5
# 2979       0
# 2980      -7
# 2981       0
#
# [2982 rows x 1 columns]

# %%
altList_01
# Out:
#      AS1_ALT  AS2_ALT  AS3_ALT  AS4_ALT  AS5_ALT  AS6_ALT  AS7_ALT
# 0         83       56       63       32       26       54       89
# 1         16       13       17       13       14       15       13
# 2         30       33       31       16       14       18       24
# 3         15       24       20       27       38       21       45
# 4         19       24       26       24       21       18       20
# ..       ...      ...      ...      ...      ...      ...      ...
# 367       38       19       41       37       23       40       40
# 368       19       28       25       18       24       25       16
# 369       19       16       19       12       15       17       10
# 370       33       18       26       18       36       45       35
# 371       69       93       81       58       52       22       27
#
# [372 rows x 7 columns]

# %%
gluList_01.columns = [1,2,3,4,5,6,7]
altList_01.columns = [1,2,3,4,5,6,7]
tgList_01.columns = [1,2,3,4,5,6,7]
waistList_01.columns = [1,2,3,4,5,6,7]
fib4List_01.columns = [1,2,3,4,5,6,7]
hba1cList_01.columns = [1,2,3,4,5,6,7]
homaList_01.columns = [1,2,3,4,5,6,7]

# %%
df_01=pd.DataFrame()

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==7:
        endData.append(homaList_01[7][i]-homaList_01[6][i])
        
df_01['homa_01'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==7:
        endData.append(homaList_01[7][i]-homaList_01[5][i])
        
df_01['homa_02'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==7:
        endData.append(homaList_01[7][i]-homaList_01[4][i])
        
df_01['homa_03'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==7:
        endData.append(homaList_01[7][i]-homaList_01[3][i])
        
df_01['homa_04'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==7:
        endData.append(homaList_01[7][i]-homaList_01[2][i])
        
df_01['homa_05'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==7:
        endData.append(homaList_01[7][i]-homaList_01[1][i])
        
df_01['homa_06'] = endData

print(df_01)
# Out:
#      homa_01    homa_02    homa_03    homa_04    homa_05    homa_06
# 0   0.047407  -0.020494  -1.089630   1.526420  -0.565432   0.131358
# 1  -0.570864  -1.299259  -0.179753  -0.167407   0.338025   0.746667
# 2   0.740741  -0.194568   0.014074  -1.282963   0.235309   0.220988
# 3   0.605432   0.143951   0.537778  -0.126420   0.678519   0.079012
# 4   0.146667  -1.063210  -0.099259  -0.897037  -0.635556   0.374074
# 5  -0.460494  -0.369383   0.131852  -0.506420   0.508395   1.514074
# 6   0.684938  -0.364198   0.263951   1.604444   1.583210   1.562469
# 7   0.474568   0.548642  -1.078025  -1.649136   1.090864  -0.062469
# 8  -0.455556  -0.201728   0.667901   0.636790   0.606790   0.609877
# 9  -0.578765   0.628395   0.524691  -0.648889   0.102222   0.000741
# 10  1.494815   1.771358   0.271358   2.936790   2.452840   1.409383
# 11  2.536296   2.183704   2.772840   2.947284   3.113580   3.341728
# 12 -0.302963  -0.354815  -3.427654   0.402963   0.726667   0.645185
# ...

# %%
df_02 = pd.DataFrame()
endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==6:
        endData.append(homaList_01[6][i]-homaList_01[5][i])
        
df_02['homa_01'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==6:
        endData.append(homaList_01[6][i]-homaList_01[4][i])
        
df_02['homa_02'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==6:
        endData.append(homaList_01[6][i]-homaList_01[3][i])
        
df_02['homa_03'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==6:
        endData.append(homaList_01[6][i]-homaList_01[2][i])
        
df_02['homa_04'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==6:
        endData.append(homaList_01[6][i]-homaList_01[1][i])
        
df_02['homa_05'] = endData

print(df_02)
# Out:
#      homa_01   homa_02   homa_03   homa_04   homa_05
# 0  -1.067654 -0.810370  0.004198 -1.065185  2.009383
# 1   1.408395  2.854321  1.976296  1.768889  3.883457
# 2  -1.061975  0.658519 -1.012099  0.043457 -0.048642
# 3   6.246667  6.540741  7.847901  7.864198  6.800988
# 4  -0.111605 -0.245432 -2.147654  0.345185  0.273333
# ..       ...       ...       ...       ...       ...
# 68  1.411111  0.611111 -0.340988  0.546667  1.439506
# 69  0.188642  0.831852  0.573827  0.945679  0.616790
# 70  1.690864  2.464198  2.617284  3.560494  3.207901
# 71 -0.257284  0.712840 -0.328642  1.910370  1.289136
# 72 -1.631605 -0.152099  0.197531  0.484568  0.764444
#
# [73 rows x 5 columns]

# %%
df_03 = pd.DataFrame()
endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==5:
        endData.append(homaList_01[5][i]-homaList_01[4][i])
        
df_03['homa_01'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==5:
        endData.append(homaList_01[5][i]-homaList_01[3][i])
        
df_03['homa_02'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==5:
        endData.append(homaList_01[5][i]-homaList_01[2][i])
        
df_03['homa_03'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==5:
        endData.append(homaList_01[5][i]-homaList_01[1][i])
        
df_03['homa_04'] = endData

print(df_03)
# Out:
#      homa_01   homa_02   homa_03   homa_04
# 0  -0.235062  0.677531  1.598272  0.303457
# 1   3.127901 -3.220247  2.586667  2.487901
# 2   0.739753 -0.097778  1.228889  1.174321
# 3   0.645926  1.560988  2.141728  2.196790
# 4   2.698519  2.216296  2.607901  2.562963
# ..       ...       ...       ...       ...
# 77  0.958765  0.360988  1.488148  1.226173
# 78 -0.180247  0.092346  0.356790 -0.061728
# 79 -0.381728  0.849383  1.809136  1.217037
# 80  2.520988  3.422222  3.548519  3.673333
# 81  0.177284 -1.751358  0.345432 -0.013333
#
# [82 rows x 4 columns]

# %%
df_04 = pd.DataFrame()
endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==4:
        endData.append(homaList_01[4][i]-homaList_01[3][i])
        
df_04['homa_01'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==4:
        endData.append(homaList_01[4][i]-homaList_01[2][i])
        
df_04['homa_02'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==4:
        endData.append(homaList_01[4][i]-homaList_01[1][i])
        
df_04['homa_03'] = endData

print(df_04)
# Out:
#      homa_01   homa_02   homa_03
# 0   0.486049  0.976049  0.980741
# 1   2.662222  0.326667  2.268148
# 2   1.305926  0.985432  1.883210
# 3   0.369136 -2.684444 -1.369877
# 4   0.721111  1.441111  1.444444
# ..       ...       ...       ...
# 58  0.357531  0.014568  1.188148
# 59  1.420741  1.421235  1.425679
# 60 -0.448889 -0.216914  0.016049
# 61  1.429877  2.504691  3.258765
# 62 -0.079506  0.468642 -0.274074
#
# [63 rows x 3 columns]

# %%
df_05 = pd.DataFrame()
endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==3:
        endData.append(homaList_01[3][i]-homaList_01[2][i])
        
df_05['homa_01'] = endData

endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==3:
        endData.append(homaList_01[3][i]-homaList_01[1][i])
        
df_05['homa_02'] = endData

print(df_05)
# Out:
#      homa_01    homa_02
# 0  -0.226914   0.175062
# 1  -0.740741  -0.740247
# 2  -0.088642  -0.179753
# 3   0.533333  -0.097284
# 4  -0.364938  -0.567901
# 5   1.660741  -0.531605
# 6   0.245309   0.489877
# 7   0.744691   1.493827
# 8   0.378889   0.755556
# 9   0.664444   1.334321
# 10 -0.005679  -0.309383
# 11  0.278025   0.546914
# 12  2.225185   1.907654
# 13 -3.098519  -1.126914
# 14  0.374074   0.309383
# 15 -1.654815  -0.579506
# 16 -0.297037   1.187654
# 17  1.426667   2.850864
# 18 -0.157778   0.679012
# 19 -0.801975  -1.573580
# 20 -0.124074  -0.251852
# 21  0.289506   0.575556
# 22  0.239630   0.476296
# 23 -0.370370 -13.296543
# 24 -0.015309   1.231358
# 25 -1.257531  -1.456049
# 26  2.296296   1.441975
# 27  1.198025  -0.240000
# 28 -1.121481  -0.031358
# 29 -1.809383  -1.598025
# 30  0.925556   1.858765
# 31 -3.148148  -1.516543
# 32 -0.031111   1.017778
# 33  2.863210   2.823704
# 34  0.150000   0.309877
# 35 -0.706420  -6.232346
# 36 -0.538272   0.374321
# ...

# %%
df_06 = pd.DataFrame()
endData = []
for i in range(len(homaList_01)):
    if data_01["phase"][i]==2:
        endData.append(homaList_01[2][i]-homaList_01[1][i])
        
df_06['homa_01'] = endData

print(df_06)
# Out:
#      homa_01
# 0   1.398519
# 1   0.620741
# 2   1.323704
# 3   0.268395
# 4  -0.000617
# 5  -1.108889
# 6  -0.229012
# 7   0.097654
# 8   0.331111
# 9   1.222840
# 10 -0.594815
# 11  1.108642
# 12  0.956667
# 13  1.030123
# 14 -0.698272
# 15 -0.502716
# 16 -0.726667
# 17  2.328889
# 18  1.366914
# 19  1.034691
# 20  0.517531
# 21  2.403951
# 22  1.609877
# 23 -0.311852
# 24  0.593333
# 25  1.217531
# 26  3.334321
# 27  1.825185
# 28  0.714568
# 29  0.852222
# 30 -0.489383
# 31  6.133827
# 32  1.123457
# 33  0.428889
# 34  1.964938
# 35 -2.850370
# 36 -0.127037
# 37  0.879877
# 38 -0.177407

# %%
df_total = pd.concat([df_01,df_02,df_03,df_04,df_05,df_06], axis=1)

# %%
df_total
# Out:
#      homa_01   homa_02   homa_03   homa_04   homa_05   homa_06   homa_01  \
# 0   0.047407 -0.020494 -1.089630  1.526420 -0.565432  0.131358 -1.067654
# 1  -0.570864 -1.299259 -0.179753 -0.167407  0.338025  0.746667  1.408395
# 2   0.740741 -0.194568  0.014074 -1.282963  0.235309  0.220988 -1.061975
# 3   0.605432  0.143951  0.537778 -0.126420  0.678519  0.079012  6.246667
# 4   0.146667 -1.063210 -0.099259 -0.897037 -0.635556  0.374074 -0.111605
# ..       ...       ...       ...       ...       ...       ...       ...
# 77       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 78       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 79       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 80       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 81       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#      homa_02   homa_03   homa_04  ...   homa_01   homa_02   homa_03   homa_04  \
# ...

# %%
df_total.to_excel('/home/ekim_reverse/study/Python.study/diff_homa.xlsx')

# %%
endData = []
for i in range(len(gluList)):
    if data["phase"][i]==7:
        endData.append(gluList[7][i]-gluList[4][i])
        
df['glu_03'] = endData
print(df)

# %%
len(endData)
# Out:
# 2726

# %%
gluList[7][1]-gluList[6][1]
# Out:
# 22

# %%
gluList.head(8)
# Out:
#        1    2    3    4    5    6    7
# 0  104.0  113  121  140  109  105  114
# 1   83.0   99  104  108   83   90  112
# 2   82.0  138  100   91   96  111  118
# 3   82.0   89  100   99  104   98  123
# 4   89.0  103  115  132  123  126  136
# 5   96.0  106  107  111  115  121  108
# 6   82.0   99  102  104  102   97  107
# 7   84.0   95  100   94  107  102  131

# %%
gluList[7][1]
# Out:
# 112

# %%
data["phase"][1]==3
# Out:
# True

# %%
data["phase"].head()
# Out:
# 0    4
# 1    3
# 2    2
# 3    6
# 4    4
# Name: phase, dtype: int64

# %%
data["phase"][1]
# Out:
# 3
