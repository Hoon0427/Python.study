# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_excel('/home/ekim_reverse/PyCode/study/Python.study/pre_03.xlsx')

# %%
data.head()
# Out:
#                 RID  DM  SEX  age  phase  glu   alt   tg      waist      fib4  \
# 0  EPI18_079_000033   1    1   48      4  140  32.0  178  76.800000  0.952007
# 1  EPI18_079_000051   1    2   73      3  104  17.0  126  92.700000  0.820026
# 2  EPI18_079_000069   1    1   52      2  138  33.0  192  91.800000  0.804626
# 3  EPI18_079_000075   1    2   58      6   98  21.0  362  85.566667  1.002506
# 4  EPI18_079_000126   1    2   50      4  132  24.0  194  89.033333  0.671461
#
#    hba1c      homa
# 0    6.2  2.316049
# 1    7.7  1.753086
# 2    5.5  3.645926
# 3    6.7  2.758519
# 4    7.7  3.454815

# %%
data = data.dropna(axis=0)

# %%
diabetes = data[data['DM']==1]

# %%
diabetes
# Out:
#                   RID  DM  SEX  age  phase  glu   alt   tg       waist  \
# 0    EPI18_079_000033   1    1   48      4  140  32.0  178   76.800000
# 1    EPI18_079_000051   1    2   73      3  104  17.0  126   92.700000
# 2    EPI18_079_000069   1    1   52      2  138  33.0  192   91.800000
# 3    EPI18_079_000075   1    2   58      6   98  21.0  362   85.566667
# 4    EPI18_079_000126   1    2   50      4  132  24.0  194   89.033333
# ..                ...  ..  ...  ...    ...  ...   ...  ...         ...
# 376  EPI18_079_009938   1    1   61      7  109  40.0  148   97.300000
# 377  EPI18_079_009963   1    1   54      3   91  25.0  168   84.500000
# 378  EPI18_079_009966   1    2   58      3   90  19.0  442   83.000000
# 379  EPI18_079_010006   1    2   56      7  112  35.0  157  111.566667
# 380  EPI18_079_010010   1    1   47      3  117  81.0  401   99.000000
#
#          fib4  hba1c      homa
# 0    0.952007    6.2  2.316049
# 1    0.820026    7.7  1.753086
# ...

# %%
normal = data[data['DM']!=1]

# %%
normal
# Out:
#                    RID  DM  SEX  age  phase  glu   alt   tg       waist  \
# 381   EPI18_079_000002   0    2   58      7   91  20.0  265   79.066667
# 382   EPI18_079_000012   0    2   54      7   78  16.0  114   79.400000
# 383   EPI18_079_000017   0    2   71      7  100  18.0   94  100.400000
# 384   EPI18_079_000019   0    2   51      7   81  18.0  107   70.900000
# 385   EPI18_079_000022   0    2   73      7   84  10.0   96   96.700000
# ...                ...  ..  ...  ...    ...  ...   ...  ...         ...
# 3042  EPI18_079_010021   0    2   72      7   82  14.0  141   84.300000
# 3043  EPI18_079_010022   0    2   67      7   93  15.0  122  102.000000
# 3044  EPI18_079_010023   0    1   73      7   92  44.0  106   85.300000
# 3045  EPI18_079_010024   0    2   58      7   90  15.0  133   89.000000
# 3046  EPI18_079_010028   0    2   53      7   88  62.0   45   76.600000
#
#           fib4  hba1c      homa
# 381   0.819107    6.2  1.797531
# 382   0.859551    5.5  1.502222
# ...

# %%
sample_01 = normal.sample(n=381, random_state=1)
sample_02 = normal.sample(n=381, random_state=2)
sample_03 = normal.sample(n=381, random_state=3)
sample_04 = normal.sample(n=381, random_state=4)
sample_05 = normal.sample(n=381, random_state=5)
sample_06 = normal.sample(n=381, random_state=6)
sample_07 = normal.sample(n=381, random_state=7)
sample_08 = normal.sample(n=381, random_state=8)
sample_09 = normal.sample(n=381, random_state=9)
sample_10 = normal.sample(n=381, random_state=10)

# %%
log_01 = pd.concat([diabetes,sample_01])
log_02 = pd.concat([diabetes,sample_02])
log_03 = pd.concat([diabetes,sample_03])
log_04 = pd.concat([diabetes,sample_04])
log_05 = pd.concat([diabetes,sample_05])
log_06 = pd.concat([diabetes,sample_06])
log_07 = pd.concat([diabetes,sample_07])
log_08 = pd.concat([diabetes,sample_08])
log_09 = pd.concat([diabetes,sample_09])
log_10 = pd.concat([diabetes,sample_10])

# %%
x = log_01[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_01['DM']

# %%
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# log = LogisticRegression() 
# result_01 = log.fit(x_train,y_train)
# Out:
# /home/ekim_reverse/.local/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
import statsmodels.api as sm
logit = sm.Logit(log_01[['DM']],x) #로지스틱 회귀분석 시행
result_01 = logit.fit()
result_01.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.091073
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8686
# Time:                        17:53:01   Log-Likelihood:                -69.397
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                9.195e-193
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_02[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_02['DM']

import statsmodels.api as sm
logit = sm.Logit(log_02[['DM']],x) #로지스틱 회귀분석 시행
result_02 = logit.fit()
result_02.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.100879
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8545
# Time:                        17:53:06   Log-Likelihood:                -76.870
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                1.540e-189
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_03[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_03['DM']

import statsmodels.api as sm
logit = sm.Logit(log_03[['DM']],x) #로지스틱 회귀분석 시행
result_03 = logit.fit()
result_03.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.096685
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8605
# Time:                        17:53:17   Log-Likelihood:                -73.674
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                6.436e-191
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_04[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_04['DM']

import statsmodels.api as sm
logit = sm.Logit(log_04[['DM']],x) #로지스틱 회귀분석 시행
result_04 = logit.fit()
result_04.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.090156
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8699
# Time:                        17:53:24   Log-Likelihood:                -68.699
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                4.594e-193
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_05[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_05['DM']

import statsmodels.api as sm
logit = sm.Logit(log_05[['DM']],x) #로지스틱 회귀분석 시행
result_05 = logit.fit()
result_05.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.086716
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8749
# Time:                        17:53:32   Log-Likelihood:                -66.078
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                3.398e-194
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_06[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_06['DM']

import statsmodels.api as sm
logit = sm.Logit(log_06[['DM']],x) #로지스틱 회귀분석 시행
result_06 = logit.fit()
result_06.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.096859
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8603
# Time:                        17:53:39   Log-Likelihood:                -73.806
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                7.341e-191
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_07[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_07['DM']

import statsmodels.api as sm
logit = sm.Logit(log_07[['DM']],x) #로지스틱 회귀분석 시행
result_07 = logit.fit()
result_07.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.092979
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8659
# Time:                        17:53:46   Log-Likelihood:                -70.850
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                3.895e-192
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_08[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_08['DM']

import statsmodels.api as sm
logit = sm.Logit(log_08[['DM']],x) #로지스틱 회귀분석 시행
result_08 = logit.fit()
result_08.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.090300
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8697
# Time:                        17:53:56   Log-Likelihood:                -68.809
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                5.125e-193
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_09[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_09['DM']

import statsmodels.api as sm
logit = sm.Logit(log_09[['DM']],x) #로지스틱 회귀분석 시행
result_09 = logit.fit()
result_09.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.097454
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8594
# Time:                        17:54:12   Log-Likelihood:                -74.260
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                1.152e-190
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x = log_10[['SEX','age','phase','glu','alt','waist','fib4','hba1c','homa']]
y = log_10['DM']

import statsmodels.api as sm
logit = sm.Logit(log_10[['DM']],x) #로지스틱 회귀분석 시행
result_10 = logit.fit()
result_10.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.094950
#          Iterations 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                     DM   No. Observations:                  762
# Model:                          Logit   Df Residuals:                      753
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 15 Jun 2020   Pseudo R-squ.:                  0.8630
# Time:                        17:54:14   Log-Likelihood:                -72.352
# converged:                       True   LL-Null:                       -528.18
# Covariance Type:            nonrobust   LLR p-value:                1.731e-191
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
