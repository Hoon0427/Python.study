# %%
import efficientnet.keras as efn
import os 
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras import layers 
from tensorflow.keras import Model 
import matplotlib.pyplot as plt
from tensorflow.python.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop

# %%
base_dir = '../../File/test_color/'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training dry pictures
train_red_dir = os.path.join(train_dir, 'red')
train_green_dir = os.path.join(train_dir, 'green')
train_blue_dir = os.path.join(train_dir, 'blue')

# Directory with our validation dry pictures
validation_red_dir = os.path.join(validation_dir, 'red')
validation_green_dir = os.path.join(validation_dir, 'green')
validation_blue_dir = os.path.join(validation_dir, 'blue')

# %%
train_datagen = ImageDataGenerator(rescale = 1./255., 
                                   rotation_range = 45, 
                                   width_shift_range = 0.2, 
                                   height_shift_range = 0.2, 
                                   shear_range = 0.2, 
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale = 1.0/255.)

train_generator = train_datagen.flow_from_directory(train_dir, 
                                                    batch_size = 20, 
                                                    class_mode = 'categorical', 
                                                    target_size = (224, 224))

validation_generator = validation_datagen.flow_from_directory(validation_dir, 
                                                              batch_size = 20, 
                                                              class_mode = 'categorical', 
                                                              target_size = (224, 224))
# Out:
# Found 3600 images belonging to 4 classes.
# Found 1800 images belonging to 4 classes.

# %%
base_model = efn.EfficientNetB0(input_shape = (224, 224, 3), include_top = False, weights = 'imagenet')

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.5)(x)
predictions = Dense(4, activation="softmax")(x)
model_final = Model(inputs = base_model.input, outputs = predictions)

# %%
model_final.compile(tf.keras.optimizers.RMSprop(lr=0.0001, decay=1e-6),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
eff_history = model_final.fit(train_generator, 
                              validation_data = validation_generator, 
                              steps_per_epoch = 20,
                              epochs = 100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 8s 424ms/step - loss: 1.3673 - accuracy: 0.7475 - val_loss: 0.3500 - val_accuracy: 0.8956
# Epoch 2/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.4467 - accuracy: 0.8750 - val_loss: 0.1832 - val_accuracy: 0.9450
# Epoch 3/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.3576 - accuracy: 0.9000 - val_loss: 0.0779 - val_accuracy: 0.9750
# Epoch 4/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.2261 - accuracy: 0.9350 - val_loss: 0.1951 - val_accuracy: 0.9578
# Epoch 5/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.1519 - accuracy: 0.9675 - val_loss: 0.1991 - val_accuracy: 0.9461
# Epoch 6/100
# 20/20 [==============================] - 8s 385ms/step - loss: 0.2195 - accuracy: 0.9600 - val_loss: 0.0405 - val_accuracy: 0.9889
# Epoch 7/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.1326 - accuracy: 0.9525 - val_loss: 0.1571 - val_accuracy: 0.9589
# Epoch 8/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.2858 - accuracy: 0.9450 - val_loss: 0.0519 - val_accuracy: 0.9867
# Epoch 9/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.1882 - accuracy: 0.9625 - val_loss: 0.0884 - val_accuracy: 0.9744
# Epoch 10/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0774 - accuracy: 0.9800 - val_loss: 0.0396 - val_accuracy: 0.9889
# Epoch 11/100
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0859 - accuracy: 0.9825 - val_loss: 0.0408 - val_accuracy: 0.9900
# Epoch 12/100
# 20/20 [==============================] - 7s 374ms/step - loss: 0.1450 - accuracy: 0.9725 - val_loss: 0.0510 - val_accuracy: 0.9872
# Epoch 13/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.1420 - accuracy: 0.9675 - val_loss: 0.0892 - val_accuracy: 0.9794
# Epoch 14/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.1311 - accuracy: 0.9750 - val_loss: 0.0786 - val_accuracy: 0.9817
# Epoch 15/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.1136 - accuracy: 0.9650 - val_loss: 0.0217 - val_accuracy: 0.9939
# Epoch 16/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.1007 - accuracy: 0.9725 - val_loss: 0.0038 - val_accuracy: 0.9983
# Epoch 17/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.0905 - accuracy: 0.9825 - val_loss: 0.0306 - val_accuracy: 0.9933
# Epoch 18/100
# 20/20 [==============================] - 8s 383ms/step - loss: 0.1214 - accuracy: 0.9750 - val_loss: 0.0229 - val_accuracy: 0.9939
# Epoch 19/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0569 - accuracy: 0.9850 - val_loss: 0.0217 - val_accuracy: 0.9939
# Epoch 20/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0814 - accuracy: 0.9775 - val_loss: 0.0247 - val_accuracy: 0.9922
# Epoch 21/100
# 20/20 [==============================] - 8s 383ms/step - loss: 0.0629 - accuracy: 0.9825 - val_loss: 0.0300 - val_accuracy: 0.9933
# Epoch 22/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0166 - accuracy: 0.9975 - val_loss: 0.0147 - val_accuracy: 0.9956
# Epoch 23/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0339 - accuracy: 0.9900 - val_loss: 0.0963 - val_accuracy: 0.9783
# Epoch 24/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0742 - accuracy: 0.9900 - val_loss: 0.0218 - val_accuracy: 0.9939
# Epoch 25/100
# 20/20 [==============================] - 8s 375ms/step - loss: 0.0765 - accuracy: 0.9850 - val_loss: 0.0244 - val_accuracy: 0.9933
# Epoch 26/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.1636 - accuracy: 0.9850 - val_loss: 0.0256 - val_accuracy: 0.9967
# Epoch 27/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.1017 - accuracy: 0.9700 - val_loss: 0.0301 - val_accuracy: 0.9956
# Epoch 28/100
# 20/20 [==============================] - 8s 383ms/step - loss: 0.0987 - accuracy: 0.9800 - val_loss: 0.0154 - val_accuracy: 0.9972
# Epoch 29/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0093 - accuracy: 0.9950 - val_loss: 0.0135 - val_accuracy: 0.9978
# Epoch 30/100
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0336 - accuracy: 0.9900 - val_loss: 0.0236 - val_accuracy: 0.9950
# Epoch 31/100
# 20/20 [==============================] - 8s 386ms/step - loss: 0.1085 - accuracy: 0.9825 - val_loss: 0.0318 - val_accuracy: 0.9944
# Epoch 32/100
# 20/20 [==============================] - 8s 385ms/step - loss: 0.0258 - accuracy: 0.9875 - val_loss: 0.0150 - val_accuracy: 0.9967
# Epoch 33/100
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0370 - accuracy: 0.9925 - val_loss: 0.0157 - val_accuracy: 0.9961
# Epoch 34/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0621 - accuracy: 0.9825 - val_loss: 0.0360 - val_accuracy: 0.9917
# Epoch 35/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.1553 - accuracy: 0.9775 - val_loss: 0.0195 - val_accuracy: 0.9961
# Epoch 36/100
# 20/20 [==============================] - 7s 374ms/step - loss: 0.0201 - accuracy: 0.9925 - val_loss: 0.0068 - val_accuracy: 0.9983
# Epoch 37/100
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0543 - accuracy: 0.9875 - val_loss: 0.0223 - val_accuracy: 0.9950
# Epoch 38/100
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0542 - accuracy: 0.9925 - val_loss: 0.0190 - val_accuracy: 0.9939
# Epoch 39/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.1006 - accuracy: 0.9850 - val_loss: 0.0293 - val_accuracy: 0.9956
# Epoch 40/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0429 - accuracy: 0.9925 - val_loss: 0.0065 - val_accuracy: 0.9994
# Epoch 41/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.1035 - accuracy: 0.9900 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 42/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0660 - accuracy: 0.9850 - val_loss: 0.0239 - val_accuracy: 0.9933
# Epoch 43/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0257 - val_accuracy: 0.9956
# Epoch 44/100
# 20/20 [==============================] - 8s 386ms/step - loss: 0.0235 - accuracy: 0.9950 - val_loss: 0.0975 - val_accuracy: 0.9806
# Epoch 45/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 0.0257 - val_accuracy: 0.9956
# Epoch 46/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0035 - accuracy: 0.9975 - val_loss: 0.0040 - val_accuracy: 0.9989
# Epoch 47/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.1066 - accuracy: 0.9900 - val_loss: 0.0063 - val_accuracy: 0.9983
# Epoch 48/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0378 - accuracy: 0.9975 - val_loss: 0.0011 - val_accuracy: 0.9994
# Epoch 49/100
# 20/20 [==============================] - 8s 382ms/step - loss: 1.9047e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9983
# Epoch 50/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0292 - accuracy: 0.9975 - val_loss: 0.0130 - val_accuracy: 0.9967
# Epoch 51/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.1568 - accuracy: 0.9825 - val_loss: 0.0281 - val_accuracy: 0.9939
# Epoch 52/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0444 - accuracy: 0.9925 - val_loss: 0.0158 - val_accuracy: 0.9978
# Epoch 53/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.0277 - accuracy: 0.9950 - val_loss: 0.0243 - val_accuracy: 0.9967
# Epoch 54/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0316 - accuracy: 0.9950 - val_loss: 0.0068 - val_accuracy: 0.9994
# Epoch 55/100
# 20/20 [==============================] - 7s 371ms/step - loss: 0.0502 - accuracy: 0.9950 - val_loss: 0.0014 - val_accuracy: 0.9994
# Epoch 56/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0025 - val_accuracy: 0.9989
# Epoch 57/100
# 20/20 [==============================] - 8s 375ms/step - loss: 0.0550 - accuracy: 0.9925 - val_loss: 0.0058 - val_accuracy: 0.9994
# Epoch 58/100
# 20/20 [==============================] - 8s 384ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0071 - val_accuracy: 0.9994
# Epoch 59/100
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0317 - accuracy: 0.9900 - val_loss: 0.0039 - val_accuracy: 0.9989
# Epoch 60/100
# 20/20 [==============================] - 8s 385ms/step - loss: 0.0661 - accuracy: 0.9950 - val_loss: 0.0013 - val_accuracy: 0.9994
# Epoch 61/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.0394 - accuracy: 0.9950 - val_loss: 0.0044 - val_accuracy: 0.9983
# Epoch 62/100
# 20/20 [==============================] - 7s 369ms/step - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.0131 - val_accuracy: 0.9961
# Epoch 63/100
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0438 - accuracy: 0.9975 - val_loss: 0.0037 - val_accuracy: 0.9983
# Epoch 64/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.1052 - accuracy: 0.9875 - val_loss: 0.0044 - val_accuracy: 0.9994
# Epoch 65/100
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0263 - accuracy: 0.9950 - val_loss: 0.0063 - val_accuracy: 0.9989
# Epoch 66/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.0017 - val_accuracy: 0.9994
# Epoch 67/100
# 20/20 [==============================] - 8s 383ms/step - loss: 0.0763 - accuracy: 0.9925 - val_loss: 2.0346e-04 - val_accuracy: 1.0000
# Epoch 68/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0638 - accuracy: 0.9850 - val_loss: 0.0019 - val_accuracy: 0.9994
# Epoch 69/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.1081 - accuracy: 0.9925 - val_loss: 0.0013 - val_accuracy: 0.9994
# Epoch 70/100
# 20/20 [==============================] - 8s 384ms/step - loss: 0.0124 - accuracy: 0.9925 - val_loss: 3.6932e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 20/20 [==============================] - 8s 385ms/step - loss: 0.0226 - accuracy: 0.9975 - val_loss: 0.0024 - val_accuracy: 0.9994
# Epoch 72/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0287 - accuracy: 0.9950 - val_loss: 0.0056 - val_accuracy: 0.9983
# Epoch 73/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0164 - accuracy: 0.9975 - val_loss: 0.0021 - val_accuracy: 0.9983
# Epoch 74/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0468 - accuracy: 0.9950 - val_loss: 0.0448 - val_accuracy: 0.9944
# Epoch 75/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.0050 - accuracy: 0.9950 - val_loss: 0.0260 - val_accuracy: 0.9961
# Epoch 76/100
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0235 - accuracy: 0.9875 - val_loss: 0.0373 - val_accuracy: 0.9961
# Epoch 77/100
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0283 - accuracy: 0.9900 - val_loss: 0.0297 - val_accuracy: 0.9956
# Epoch 78/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0232 - accuracy: 0.9950 - val_loss: 0.0042 - val_accuracy: 0.9994
# Epoch 79/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0230 - accuracy: 0.9975 - val_loss: 0.0164 - val_accuracy: 0.9972
# Epoch 80/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0384 - accuracy: 0.9975 - val_loss: 0.0037 - val_accuracy: 0.9994
# Epoch 81/100
# 20/20 [==============================] - 7s 374ms/step - loss: 0.0367 - accuracy: 0.9900 - val_loss: 0.0022 - val_accuracy: 0.9989
# Epoch 82/100
# 20/20 [==============================] - 7s 372ms/step - loss: 0.0288 - accuracy: 0.9950 - val_loss: 0.0030 - val_accuracy: 0.9994
# Epoch 83/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0093 - accuracy: 0.9950 - val_loss: 0.0065 - val_accuracy: 0.9978
# Epoch 84/100
# 20/20 [==============================] - 8s 385ms/step - loss: 0.0146 - accuracy: 0.9975 - val_loss: 0.0014 - val_accuracy: 0.9994
# Epoch 85/100
# 20/20 [==============================] - 7s 372ms/step - loss: 6.4509e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9989
# Epoch 86/100
# 20/20 [==============================] - 8s 383ms/step - loss: 5.0113e-04 - accuracy: 1.0000 - val_loss: 6.7674e-04 - val_accuracy: 0.9994
# Epoch 87/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0451 - accuracy: 0.9950 - val_loss: 0.0034 - val_accuracy: 0.9994
# Epoch 88/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0257 - accuracy: 0.9950 - val_loss: 0.0673 - val_accuracy: 0.9933
# Epoch 89/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0725 - accuracy: 0.9900 - val_loss: 0.0340 - val_accuracy: 0.9956
# Epoch 90/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0091 - accuracy: 0.9950 - val_loss: 0.0015 - val_accuracy: 0.9994
# Epoch 91/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.0385 - accuracy: 0.9950 - val_loss: 0.0011 - val_accuracy: 0.9994
# Epoch 92/100
# 20/20 [==============================] - 8s 384ms/step - loss: 7.9823e-05 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 0.9994
# Epoch 93/100
# 20/20 [==============================] - 8s 382ms/step - loss: 0.0291 - accuracy: 0.9950 - val_loss: 0.0101 - val_accuracy: 0.9983
# Epoch 94/100
# 20/20 [==============================] - 7s 367ms/step - loss: 0.0522 - accuracy: 0.9950 - val_loss: 0.0039 - val_accuracy: 0.9989
# Epoch 95/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0936 - accuracy: 0.9900 - val_loss: 0.0071 - val_accuracy: 0.9978
# Epoch 96/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0901 - accuracy: 0.9875 - val_loss: 2.0368e-05 - val_accuracy: 1.0000
# Epoch 97/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0298 - accuracy: 0.9900 - val_loss: 4.3009e-06 - val_accuracy: 1.0000
# Epoch 98/100
# 20/20 [==============================] - 8s 385ms/step - loss: 1.2497e-04 - accuracy: 1.0000 - val_loss: 4.6543e-07 - val_accuracy: 1.0000
# Epoch 99/100
# 20/20 [==============================] - 8s 376ms/step - loss: 4.2560e-04 - accuracy: 1.0000 - val_loss: 1.5576e-07 - val_accuracy: 1.0000
# Epoch 100/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.0048 - accuracy: 0.9975 - val_loss: 9.3113e-07 - val_accuracy: 1.0000
