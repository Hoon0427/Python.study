# %%
import cv2
import pandas as pd
import numpy as np

import matplotlib.pylab as plt
# %matplotlib inline

# %%
image = cv2.imread('/home/mango/python/Python.study/oil_test_01.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# plt.xticks([])     #x축 눈금 지우기
# plt.yticks([])     #y축 눈금 지우기
plt.imshow(image)
plt.show()

# %% [markdown]
# # 1. blurring

# %%
img = cv2.imread('/home/mango/python/Python.study/oil_test_01.jpg')
img_gray = cv2.imread('/home/mango/python/Python.study/oil_test_01.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
blur = cv2.GaussianBlur(img_gray, ksize = (5,5), sigmaX = 0)
plt.imshow(blur)

# %%
test_01 = cv2.cvtColor(blur, cv2.COLOR_GRAY2RGB)
plt.imshow(test_01)

# %% [markdown]
# # . Threshold

# %%
ret, thr1 = cv2.threshold(blur, 0, 255, cv2.THRESH_OTSU)

# %%
plt.imshow(thr1)

# %% [markdown]
# # . Edge Detection

# %%
canny = cv2.Canny(thr1, 70, 100)
sobel = cv2.Sobel(img_gray, cv2.CV_8U, 1, 0, 3)
laplacian = cv2.Laplacian(img_gray, cv2.CV_8U, ksize=3)

# %%
plt.imshow(canny)

# %%
plt.imshow(sobel)

# %%
plt.imshow(laplacian)

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7,7))
closed = cv2.morphologyEx(edge, cv2.MORPH_CLOSE, kernel)
plt.imshow( closed)

# %%
contours, _ = cv2.findContours(closed.copy(),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
total = 0

# %%
contours_image = cv2.drawContours(img, contours, -1, (0,255,0), 3)
plt.imshow(contours_image)

# %%
contours_xy = np.array(contours)
contours_xy.shape
# Out:
# <ipython-input-49-c176915b3f65>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   contours_xy = np.array(contours)
# (565,)

# %%
# x의 min과 max 찾기
x_min, x_max = 0,0
value = list()
for i in range(len(contours_xy)):
    for j in range(len(contours_xy[i])):
        value.append(contours_xy[i][j][0][0]) #네번째 괄호가 0일때 x의 값
        x_min = min(value)
        x_max = max(value)
print(x_min)
print(x_max)
 
# y의 min과 max 찾기
y_min, y_max = 0,0
value = list()
for i in range(len(contours_xy)):
    for j in range(len(contours_xy[i])):
        value.append(contours_xy[i][j][0][1]) #네번째 괄호가 0일때 x의 값
        y_min = min(value)
        y_max = max(value)
print(y_min)
print(y_max)
# Out:
# 0
# 1439
# 0
# 1439

# %%
# image trim 하기
x = x_min
y = y_min
w = x_max-x_min
h = y_max-y_min

# %%
img_trim = img[y:y+h, x:x+w]
cv2.imwrite('org_trim.jpg', img_trim)
org_image = cv2.imread('org_trim.jpg')

# %%
plt.imshow(org_image)
